# %%
import pandas as pd
result = pd.read_csv('wuxi_house_price.csv',encoding='gbk')
result
# Out:
#      Unnamed: 0                       _id                                 位置  \
# 0             0  5b7f6dd5e7986a2e106aad9c                [?梁溪?崇安?]?锡沪东路,近广和路
# 1             1  5b7f6dd6e7986a2e106aad9d                [?滨湖?蠡湖?]?金城西路,近金水路
# 2             2  5b7f6dd6e7986a2e106aad9e                 [?锡山?鹅湖?]?甘虞路,近蘅芳路
# 3             3  5b7f6dd6e7986a2e106aad9f               [?滨湖?太湖?]?贡湖大道,近塘铁桥路
# 4             4  5b7f6dd6e7986a2e106aada0                [?新吴?旺庄?]?长江南路，近新华路
# 5             5  5b7f6dd6e7986a2e106aada1    [?新吴?新安?]?太科园具区路与净慧东道交汇处（大桥实...
# 6             6  5b7f6dd6e7986a2e106aada2              [?梁溪?北塘?]?江海西路与会岸路交汇处
# 7             7  5b7f6dd6e7986a2e106aada3                [?新吴?新安?]?净慧东道，近和风路
# 8             8  5b7f6dd6e7986a2e106aada4  [?梁溪?北塘?]?江海西路888号 （原金山北科技园会岸路...
# 9             9  5b7f6dd6e7986a2e106aada5               [?锡山?东亭?]?二泉东路，近团结中路
# 10           10  5b7f6dd6e7986a2e106aada6                  [?梁溪?北塘?]?盛岸路近钱皋路
# ...

# %%
result.dropna()
# Out:
#      Unnamed: 0                       _id                                 位置  \
# 0             0  5b7f6dd5e7986a2e106aad9c                [?梁溪?崇安?]?锡沪东路,近广和路
# 1             1  5b7f6dd6e7986a2e106aad9d                [?滨湖?蠡湖?]?金城西路,近金水路
# 2             2  5b7f6dd6e7986a2e106aad9e                 [?锡山?鹅湖?]?甘虞路,近蘅芳路
# 3             3  5b7f6dd6e7986a2e106aad9f               [?滨湖?太湖?]?贡湖大道,近塘铁桥路
# 4             4  5b7f6dd6e7986a2e106aada0                [?新吴?旺庄?]?长江南路，近新华路
# 6             6  5b7f6dd6e7986a2e106aada2              [?梁溪?北塘?]?江海西路与会岸路交汇处
# 7             7  5b7f6dd6e7986a2e106aada3                [?新吴?新安?]?净慧东道，近和风路
# 8             8  5b7f6dd6e7986a2e106aada4  [?梁溪?北塘?]?江海西路888号 （原金山北科技园会岸路...
# 9             9  5b7f6dd6e7986a2e106aada5               [?锡山?东亭?]?二泉东路，近团结中路
# 11           11  5b7f6dd6e7986a2e106aada7                [?滨湖?马山?]?人民东路,近刘闾路
# 12           12  5b7f6dd6e7986a2e106aada8    [?锡山?锡北?]?政丰路与泾声路交汇处（泉山文化公园对...
# ...

# %%
import numpy as np
result.head()
# Out:
#    Unnamed: 0                       _id                    位置     名称       均价
# 0           0  5b7f6dd5e7986a2e106aad9c   [?梁溪?崇安?]?锡沪东路,近广和路  中洲崇安府  19500.0
# 1           1  5b7f6dd6e7986a2e106aad9d   [?滨湖?蠡湖?]?金城西路,近金水路  蠡湖金茂府  31000.0
# 2           2  5b7f6dd6e7986a2e106aad9e    [?锡山?鹅湖?]?甘虞路,近蘅芳路  中洲花溪樾  14000.0
# 3           3  5b7f6dd6e7986a2e106aad9f  [?滨湖?太湖?]?贡湖大道,近塘铁桥路  中锐星公元  30000.0
# 4           4  5b7f6dd6e7986a2e106aada0   [?新吴?旺庄?]?长江南路，近新华路  正大万物城  13000.0

# %%
col = result['均价']
col.head()
# Out:
# 0    19500.0
# 1    31000.0
# 2    14000.0
# 3    30000.0
# 4    13000.0
# Name: 均价, dtype: float64

# %%
col[np.abs(col) > 2000]
# Out:
# 0      19500.0
# 1      31000.0
# 2      14000.0
# 3      30000.0
# 4      13000.0
# 6      16500.0
# 7      12000.0
# 8      14000.0
# 9      15500.0
# 12     12000.0
# 14     12000.0
# 15     16800.0
# 16     23000.0
# 17     28000.0
# 18     12000.0
# 19     16500.0
# 20     20000.0
# 21     16200.0
# 22     30000.0
# 23     16500.0
# 24     13000.0
# 25     12000.0
# 26     12500.0
# 27     35000.0
# 28     22400.0
# 29     19000.0
# 32     19000.0
# 33     20000.0
# 34     26000.0
# 35     14000.0
#         ...
# 560    25000.0
# 561    16500.0
# 563    20000.0
# 564    16000.0
# 566    16000.0
# 569    12000.0
# 570    20000.0
# 571    35000.0
# 574     7500.0
# 575     8000.0
# 576     3500.0
# 577     5500.0
# 578    11000.0
# 582     7500.0
# 583    13500.0
# 584    15000.0
# 585     6800.0
# 586    10500.0
# 587     9800.0
# 597    15000.0
# 598     9306.0
# 599    10000.0
# 601    13000.0
# 603     6000.0
# 612     6200.0
# 614     4000.0
# 621     8500.0
# 625     6800.0
# ...

# %%
result.mean()
# Out:
# Unnamed: 0      323.000000
# 均价            12950.538244
# dtype: float64
